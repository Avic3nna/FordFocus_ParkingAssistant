# %%
import cv2 #for 3.8 the cv2.pyd is copied
import numpy as np
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.5.5'

# %%
def show_webcam(mirror=False):
    cam = cv2.VideoCapture(1)
    while True:
        ret_val, img = cam.read()
        if mirror: 
            img = cv2.flip(img, 1)
        img = cv2.resize(img,(1280,720),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
        cv2.imshow('my webcam', img)
        if cv2.waitKey(1) == 27: 
            break  # esc to quit
    cv2.destroyAllWindows()

# %%
def main():
    show_webcam(mirror=True)


if __name__ == '__main__':
    main()

# %%
# distance was 5.5 Omar foot on the last pictures

img = cv2.imread('./left_top_gopro/with2.jpg',0)
top_img = img[:550,:]
bottom_img = img[551:,:]
#img = cv2.resize(img,(1280,720),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)


top_img = cv2.GaussianBlur(top_img,(13,13),2)
top_img = cv2.Canny(top_img, 0, 150)


bottom_img = cv2.GaussianBlur(bottom_img,(13,13),2)
bottom_img = cv2.Canny(bottom_img, 0, 150)




print(np.sum(img))

# cv2.imshow('frame', img)
# cv2.waitKey(0)
# Out:
# 302982453

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (15, 10))
rows = 2
columns = 1


fig.add_subplot(rows, columns, 1)
plt.imshow(top_img)
plt.title(np.sum(top_img))

fig.add_subplot(rows, columns, 2)
plt.imshow(bottom_img)
plt.title(np.sum(bottom_img))

                
plt.show()

# %%
image = cv2.imread('./left_top_gopro/with2.jpg')[:500,:]
image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
se=cv2.getStructuringElement(cv2.MORPH_RECT , (8,8))
bg=cv2.morphologyEx(image, cv2.MORPH_DILATE, se)
out_gray=cv2.divide(image, bg, scale=255)
img = cv2.GaussianBlur(out_gray,(13,13),2)
img = cv2.Canny(img, 0, 150)
out_binary=cv2.threshold(out_gray, 0, 255, cv2.THRESH_OTSU )[1] 

cv2.imshow('frame', out_binary)
cv2.waitKey(0)
# Out:
# -1
